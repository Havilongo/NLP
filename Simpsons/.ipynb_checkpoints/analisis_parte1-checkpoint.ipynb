# %%
import pandas as pd

# %% [markdown]
# - unificar episodes y episodes 2
# - mirar la tabla de guion como conectamos con episodios

# %%
episodios = pd.read_csv('https://raw.githubusercontent.com/Havilongo/NLP/main/Simpsons/Data/episode.csv')
categoria_episodio = pd.read_csv('https://raw.githubusercontent.com/Havilongo/NLP/main/Simpsons/Data/keyword.csv')
episodios2 = pd.read_csv('https://raw.githubusercontent.com/Havilongo/NLP/main/Simpsons/Data/simpsons_episodes.csv')

# %%
episodios.columns
# Out:
# Index(['episode_id', 'season', 'episode', 'number_in_series', 'title',
#        'summary', 'air_date', 'episode_image', 'rating', 'votes'],
#       dtype='object')

# %%
categoria_episodio.columns
# Out:
# Index(['episode_id', 'keyword'], dtype='object')

# %%
categoria_episodio.loc[categoria_episodio['episode_id'] == 'S7-E6']
# Out:
#    episode_id                      keyword
# 0       S7-E6                 3d animation
# 1       S7-E6            halloween episode
# 2       S7-E6                    nightmare
# 3       S7-E6               1930s to 2020s
# 4       S7-E6                        dream
# 5       S7-E6                        giant
# 6       S7-E6                  advertising
# 7       S7-E6                     dumpster
# 8       S7-E6    cartoon reality crossover
# 9       S7-E6             part live action
# 10      S7-E6                    halloween
# 11      S7-E6              halloween spoof
# 23      S7-E6    nightmare becomes reality
# 24      S7-E6               person on fire
# 25      S7-E6  reference to freddy krueger
# 26      S7-E6           advertising jingle
# 27      S7-E6                        alien
# 28      S7-E6                        donut
# 29      S7-E6                  utah teapot
# 30      S7-E6                 2d animation

# %%
episodios2.columns
# Out:
# Index(['index', 'id', 'image_url', 'imdb_rating', 'imdb_votes',
#        'number_in_season', 'number_in_series', 'original_air_date',
#        'original_air_year', 'production_code', 'season', 'title',
#        'us_viewers_in_millions', 'video_url', 'views'],
#       dtype='object')

# %%
episodios['rating']
# Out:
# 0      8.1
# 1      7.8
# 2      7.4
# 3      7.7
# 4      8.0
#       ...
# 678    6.2
# 679    4.3
# 680    6.5
# 681    7.2
# 682    6.8
# Name: rating, Length: 683, dtype: float64

# %%
episodios.head(3)
# Out:
#   episode_id  season  episode  number_in_series  \
# 0      S1-E1       1        1                 1
# 1      S1-E2       1        2                 2
# 2      S1-E3       1        3                 3
#
#                                title  \
# 0  Simpsons Roasting on an Open Fire
# 1                    Bart the Genius
# 2                    Homer's Odyssey
#
#                                              summary    air_date  \
# 0  The family is forced to spend all of their sav...  1989-12-17
# 1  Bart ends up at a school for gifted children a...  1990-01-14
# 2  After losing his job, Homer contemplates endin...  1990-01-21
#
#                                        episode_image  rating   votes
# 0  https://m.media-amazon.com/images/M/MV5BZjJjMz...     8.1  5499.0
# 1  https://m.media-amazon.com/images/M/MV5BOTA0MT...     7.8  3456.0
# 2  https://m.media-amazon.com/images/M/MV5BMzQ3M2...     7.4  3034.0

# %%
columnas_a_eliminar = ['rating', 'votes']
episodios = episodios.drop(columnas_a_eliminar, axis=1)

# %%
columnas_a_eliminar2 = ['index', 'id', 'image_url', 'number_in_season',	'number_in_series',	'original_air_date', 'original_air_year','production_code',	'season', 'video_url', 'views']
episodios2 = episodios2.drop(columnas_a_eliminar2, axis=1)

# %%
episodios_total = pd.merge(episodios, episodios2, on='title', how='left')

# %%
categorias = categoria_episodio[categoria_episodio['keyword'].map(categoria_episodio['keyword'].value_counts()) >= 7]

# %%
categorias
# Out:
#      episode_id    keyword
# 10        S7-E6  halloween
# 14        S1-E1  christmas
# 177       S2-E3  halloween
# 450       S3-E7  halloween
# 786       S4-E5  halloween
# 984       S5-E5  halloween
# 1192      S6-E6  halloween
# 1475     S7-E11  christmas
# 1630      S8-E1  halloween
# 1888      S9-E4  halloween
# 1925     S9-E10  christmas
# 2065     S10-E4  halloween
# 2176     S11-E4  halloween
# 2210     S11-E9  christmas
# 2335     S12-E1  halloween
# 2370     S12-E8  christmas
# 2456     S13-E1  halloween
# 2473     S13-E6  christmas
# 2565     S14-E1  halloween
# 2666     S15-E1  halloween
# 2691     S15-E7  christmas
# 2779     S16-E1  halloween
# 2903     S17-E4  halloween
# 2917     S17-E9  christmas
# 3001     S18-E4  halloween
# 3046     S18-E9  christmas
# 3167     S23-E3  halloween
# 3309     S23-E9  christmas
# 3415     S24-E2  halloween
# 3523     S25-E2  halloween
# 3579     S25-E8  christmas
# 3719     S26-E4  halloween
# 3755     S26-E9  christmas
# 3879     S27-E4  halloween
# 3915     S27-E5  halloween
# 4059     S28-E4  halloween
# 4066    S28-E10  christmas
# 4173     S19-E5  halloween
# 4402     S20-E4  christmas
# 4403     S20-E4  halloween
# 4698     S21-E4  halloween
# 4942     S22-E4  halloween
# 4994     S22-E8  christmas
# 5421    S31-E10  christmas
# 5812     S29-E4  halloween
# 6201     S30-E4  halloween
# 6787     S31-E4  halloween

# %%
categorias = categorias[categorias['keyword'].isin(['halloween', 'christmas'])]

# %%
categorias['keyword'].value_counts()
# Out:
# keyword
# halloween    31
# christmas    16
# Name: count, dtype: int64

# %%
episodios_categorias = pd.merge(episodios_total, categorias, on='episode_id', how='left')

# %%
registro_a_eliminar = episodios_categorias[(episodios_categorias['episode_id'] == 'S20-E4') & (episodios_categorias['keyword'] == 'christmas')]
indice_registro = registro_a_eliminar.index

episodios_categorias.drop(indice_registro, inplace=True)

# %%
episodios_categorias.to_csv('files/episodios_clean.csv')

# %%
ep = pd.read_csv('files/episodios_clean.csv')

# %%
ep[ep['imdb_rating'].notnull()]
# Out:
#      Unnamed: 0 episode_id  season  episode  number_in_series  \
# 0             0      S1-E1       1        1                 1
# 1             1      S1-E2       1        2                 2
# 2             2      S1-E3       1        3                 3
# 3             3      S1-E4       1        4                 4
# 4             4      S1-E5       1        5                 5
# ..          ...        ...     ...      ...               ...
# 677         678    S23-E20      23       20               506
# 679         680    S23-E22      23       22               508
# 680         681     S24-E1      24        1               509
# 681         682     S24-E2      24        2               510
# 682         683     S24-E3      24        3               511
#
#                                  title  \
# 0    Simpsons Roasting on an Open Fire
# 1                      Bart the Genius
# 2                      Homer's Odyssey
# 3        There's No Disgrace Like Home
# 4                     Bart the General
# ..                                 ...
# 677             The Spy Who Learned Me
# 679                     Lisa Goes Gaga
# 680                    Moonshine River
# 681          Treehouse of Horror XXIII
# 682         Adventures in Baby-Getting
#
#                                                summary    air_date  \
# 0    The family is forced to spend all of their sav...  1989-12-17
# 1    Bart ends up at a school for gifted children a...  1990-01-14
# 2    After losing his job, Homer contemplates endin...  1990-01-21
# 3    After being embarrassed by the rest of the fam...  1990-01-28
# 4    After being beaten up by Nelson Muntz one too ...  1990-02-04
# ..                                                 ...         ...
# 677  Homer uses his paid sick leave to improve his ...  2012-05-06
# 679  After a desperate attempt by Lisa to become mo...  2012-05-20
# 680  The Simpsons go back to New York City so that ...  2012-09-30
# 681  A black hole threatens to swallow Springfield,...  2012-10-07
# 682  Marge decides that she wants another baby, but...  2012-11-04
#
#                                          episode_image  imdb_rating  \
# 0    https://m.media-amazon.com/images/M/MV5BZjJjMz...          8.2
# 1    https://m.media-amazon.com/images/M/MV5BOTA0MT...          7.8
# 2    https://m.media-amazon.com/images/M/MV5BMzQ3M2...          7.5
# 3    https://m.media-amazon.com/images/M/MV5BOTZmNm...          7.8
# 4    https://m.media-amazon.com/images/M/MV5BMzk4ZD...          8.1
# ..                                                 ...          ...
# 677  https://m.media-amazon.com/images/M/MV5BYWNlND...          6.9
# 679  https://m.media-amazon.com/images/M/MV5BNDk4Mj...          4.5
# 680  https://m.media-amazon.com/images/M/MV5BMjEzOT...          6.4
# 681  https://m.media-amazon.com/images/M/MV5BMjMxMz...          7.3
# 682  https://m.media-amazon.com/images/M/MV5BMTY4NT...          6.9
#
#      imdb_votes  us_viewers_in_millions    keyword
# 0        3734.0                   26.70  christmas
# 1        1973.0                   24.50        NaN
# 2        1709.0                   27.50        NaN
# 3        1701.0                   20.20        NaN
# 4        1732.0                   27.10        NaN
# ..          ...                     ...        ...
# 677       405.0                    4.84        NaN
# 679      1215.0                    4.82        NaN
# 680       597.0                    8.08        NaN
# 681       600.0                    6.57  halloween
# 682       460.0                    5.65        NaN
#
# [542 rows x 13 columns]

# %%
def eda (dataframe):
    """
    Realiza un análisis exploratorio básico de un DataFrame, mostrando información sobre duplicados,
    valores nulos, tipos de datos, valores únicos para columnas categóricas y estadísticas descriptivas
    para columnas categóricas y numéricas, agrupadas por la columna de control.

    Parámetros:
    - dataframe (DataFrame): El DataFrame que se va a explorar.

    Returns: 
    No devuelve nada directamente, pero imprime en la consola la información exploratoria.
    """
    
    print(f"Los duplicados que tenemos en el conjunto de datos son: {dataframe.duplicated().sum()}")
    print("\n ..................... \n")
    
    
    # generamos un DataFrame para los valores nulos
    print("Los nulos que tenemos en el conjunto de datos son:")
    df_nulos = pd.DataFrame(dataframe.isnull().sum() / dataframe.shape[0] * 100, columns = ["%_nulos"])
    display(df_nulos[df_nulos["%_nulos"] > 0])
    
    print("\n ..................... \n")
    print(f"Los tipos de las columnas son:")
    display(pd.DataFrame(dataframe.dtypes, columns = ["tipo_dato"]))
    
    
    print("\n ..................... \n")
    print("Los valores que tenemos para las columnas categóricas son: ")
    dataframe_categoricas = dataframe.select_dtypes(include = "O")
    
    for col in dataframe_categoricas.columns:
        print(f"La columna {col.upper()} tiene las siguientes valore únicos:")
        display(pd.DataFrame(dataframe[col].value_counts()).head())    
    
    
    print("\n ..................... \n")
    print("Los valores que tenemos para las columnas numéricas son: ")
    dataframe_numericas = dataframe.select_dtypes(include='number')
    
    for col in dataframe_numericas.columns:
        print(f"La columna {col.upper()} tiene las siguientes valore únicos:")
        display(pd.DataFrame(dataframe[col].value_counts()).head())

# %%
eda(ep)
# Out:
# Los duplicados que tenemos en el conjunto de datos son: 0
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                           %_nulos
# imdb_rating             20.644217
# imdb_votes              20.644217
# us_viewers_in_millions  21.083455
# keyword                 93.265007
#  .....................
#
# Los tipos de las columnas son:
#                        tipo_dato
# Unnamed: 0                 int64
# episode_id                object
# season                     int64
# episode                    int64
# number_in_series           int64
# title                     object
# summary                   object
# air_date                  object
# episode_image             object
# imdb_rating              float64
# imdb_votes               float64
# us_viewers_in_millions   float64
# keyword                   object
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna EPISODE_ID tiene las siguientes valore únicos:
#             count
# episode_id
# S1-E1           1
# S13-E18         1
# S13-E10         1
# S13-E11         1
# S13-E12         1
# La columna TITLE tiene las siguientes valore únicos:
#                                    count
# title
# Simpsons Roasting on an Open Fire      1
# I Am Furious Yellow                    1
# Half-Decent Proposal                   1
# The Bart Wants What It Wants           1
# The Lastest Gun in the West            1
# La columna SUMMARY tiene las siguientes valore únicos:
#                                                     count
# summary
# The family is forced to spend all of their savi...      1
# Bart's comic about Homer becomes a hit on-line,...      1
# Marge's high school sweetheart Artie Ziff retur...      1
# Bart breaks up with his new girlfriend Greta, b...      1
# Bart meets a retired cowboy movie star and conv...      1
# La columna AIR_DATE tiene las siguientes valore únicos:
#             count
# air_date
# 2005-05-08      2
# 2013-05-19      2
# 2003-05-18      2
# 1996-05-19      2
# 2007-05-20      2
# La columna EPISODE_IMAGE tiene las siguientes valore únicos:
#                                                     count
# episode_image
# https://m.media-amazon.com/images/M/MV5BZjJjMzM...      1
# https://m.media-amazon.com/images/M/MV5BOTgwOTd...      1
# https://m.media-amazon.com/images/M/MV5BN2E1Yjl...      1
# https://m.media-amazon.com/images/M/MV5BMjY3ZTg...      1
# https://m.media-amazon.com/images/M/MV5BNDA2OTQ...      1
# La columna KEYWORD tiene las siguientes valore únicos:
#            count
# keyword
# halloween     31
# christmas     15
#  .....................
#
# Los valores que tenemos para las columnas numéricas son:
# La columna UNNAMED: 0 tiene las siguientes valore únicos:
#             count
# Unnamed: 0
# 0               1
# 458             1
# 450             1
# 451             1
# 452             1
# La columna SEASON tiene las siguientes valore únicos:
#         count
# season
# 6          25
# 7          25
# 8          25
# 9          25
# 3          24
# La columna EPISODE tiene las siguientes valore únicos:
#          count
# episode
# 1           31
# 8           31
# 2           31
# 12          31
# 11          31
# La columna NUMBER_IN_SERIES tiene las siguientes valore únicos:
#                   count
# number_in_series
# 1                     1
# 287                   1
# 279                   1
# 280                   1
# 281                   1
# La columna IMDB_RATING tiene las siguientes valore únicos:
#              count
# imdb_rating
# 7.3             43
# 7.1             39
# 6.9             39
# 7.0             38
# 7.2             34
# La columna IMDB_VOTES tiene las siguientes valore únicos:
#             count
# imdb_votes
# 585.0           5
# 562.0           5
# 554.0           5
# 580.0           4
# 482.0           4
# La columna US_VIEWERS_IN_MILLIONS tiene las siguientes valore únicos:
#                         count
# us_viewers_in_millions
# 14.4                        8
# 15.1                        6
# 11.8                        5
# 8.3                         5
# 8.5                         5

# %% [markdown]
# LLeno los NA de la columna keyword con la palabra 'comun', para diferenciarlos de especiales navidad y halloween.

# %%
ep['keyword'].fillna('comun', inplace=True)

# %%
col = ['imdb_rating','imdb_votes','us_viewers_in_millions']
ep[col] = ep[col].fillna('desconocido')

# %%
ep_nulos = pd.DataFrame(ep.isnull().sum() / ep.shape[0] * 100, columns = ["%_nulos"])
ep_nulos[ep_nulos["%_nulos"] > 0]
# Out:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []

# %%
ep.columns
# Out:
# Index(['Unnamed: 0', 'id', 'season', 'episode', 'number_in_series', 'title',
#        'summary', 'date', 'image', 'imdb', 'imdb_votes',
#        'us_viewers_in_millions', 'tipe'],
#       dtype='object')

# %%
ep.columns = ['Unnamed: 0', 'id', 'season', 'episode', 'number_in_series',
       'title', 'summary', 'date', 'image', 'imdb',
       'imdb_votes', 'us_viewers_in_millions', 'tipe']

# %%
ep.to_csv('files/clean_files/episodios_clean.csv')

# %% [markdown]
# ## Cargo los demas

# %%
premios_c = pd.read_csv('https://raw.githubusercontent.com/Havilongo/NLP/main/Simpsons/Data/character_award.csv')
premios = pd.read_csv('https://raw.githubusercontent.com/Havilongo/NLP/main/Simpsons/Data/award.csv')

# %%
pd.DataFrame(premios_c.isnull().sum() / premios_c.shape[0] * 100, columns = ["%_nulos"])
# Out:
#            %_nulos
# award_id       0.0
# character      0.0

# %%
premios_c.duplicated().sum()
# Out:
# 4

# %%
premios_c = premios_c.drop_duplicates()

# %%
premios_c.to_csv('files/clean_files/personajes_premiados_doblaje.csv')

# %%
premios.duplicated().sum()
# Out:
# 0

# %%
premios[premios['episode_id'].isnull()]
# Out:
#       award_id           organization  year      award_category  \
# 0          100     Golden Globes, USA  2003        Golden Globe
# 560        660  Primetime Emmy Awards  1998      Primetime Emmy
# 595        695  Primetime Emmy Awards  1996      Primetime Emmy
# 596        696  Primetime Emmy Awards  1996      Primetime Emmy
# 597        697  Primetime Emmy Awards  1996      Primetime Emmy
# ...        ...                    ...   ...                 ...
# 1238      1338    Young Artist Awards  2004  Young Artist Award
# 1239      1339    Young Artist Awards  2004  Young Artist Award
# 1240      1340    Young Artist Awards  2004  Young Artist Award
# 1241      1341    Young Artist Awards  2002  Young Artist Award
# 1243      1343         Peabody Awards  1997       Peabody Award
#
#                                                 award            person  \
# 0          Best Television Series - Comedy or Musical               NaN
# 560                Outstanding Voice-Over Performance       Hank Azaria
# 595                      Outstanding Music and Lyrics       Alf Clausen
# 596                      Outstanding Music and Lyrics       Bill Oakley
# 597                      Outstanding Music and Lyrics    Josh Weinstein
# ...                                               ...               ...
# 1238    Most Popular Mom & Pop in a Television Series      Julie Kavner
# 1239    Most Popular Mom & Pop in a Television Series  Dan Castellaneta
# 1240  Best Family Television Series (Comedy or Drama)               NaN
# 1241                     Best Family TV Comedy Series               NaN
# 1243                                              NaN               NaN
#
#                  role episode_id  season         song   result
# 0                 NaN        NaN     NaN          NaN  Nominee
# 560               NaN        NaN     NaN          NaN   Winner
# 595          composer        NaN     NaN  Señor Burns  Nominee
# 596          lyricist        NaN     NaN  Señor Burns  Nominee
# 597          lyricist        NaN     NaN  Señor Burns  Nominee
# ...               ...        ...     ...          ...      ...
# 1238              NaN        NaN     NaN          NaN   Winner
# 1239              NaN        NaN     NaN          NaN   Winner
# 1240  Comedy or Drama        NaN     NaN          NaN  Nominee
# 1241              NaN        NaN     NaN          NaN  Nominee
# 1243              NaN        NaN     NaN          NaN   Winner
#
# [391 rows x 11 columns]

# %%
premios['result'].value_counts()
# Out:
# result
# Nominee    805
# Winner     439
# Name: count, dtype: int64

# %%
premios[premios['result'] == 'Nominee']
# Out:
#       award_id                   organization  year      award_category  \
# 0          100             Golden Globes, USA  2003        Golden Globe
# 22         122          Primetime Emmy Awards  2019      Primetime Emmy
# 23         123          Primetime Emmy Awards  2019      Primetime Emmy
# 26         126          Primetime Emmy Awards  2018      Primetime Emmy
# 27         127          Primetime Emmy Awards  2018      Primetime Emmy
# ...        ...                            ...   ...                 ...
# 1235      1335  Writers Guild of America, USA  2003      WGA Award (TV)
# 1236      1336  Writers Guild of America, USA  2003      WGA Award (TV)
# 1237      1337  Writers Guild of America, USA  2003      WGA Award (TV)
# 1240      1340            Young Artist Awards  2004  Young Artist Award
# 1241      1341            Young Artist Awards  2002  Young Artist Award
#
#                                                 award            person  \
# 0          Best Television Series - Comedy or Musical               NaN
# 22       Outstanding Character Voice-Over Performance       Hank Azaria
# 23       Outstanding Character Voice-Over Performance       Fox Network
# 26       Outstanding Character Voice-Over Performance  Dan Castellaneta
# 27       Outstanding Character Voice-Over Performance       Fox Network
# ...                                               ...               ...
# 1235                                        Animation        John Frink
# 1236                                        Animation         Don Payne
# 1237                                        Animation       Matt Selman
# 1240  Best Family Television Series (Comedy or Drama)               NaN
# 1241                     Best Family TV Comedy Series               NaN
#
#                  role episode_id  season song   result
# 0                 NaN        NaN     NaN  NaN  Nominee
# 22                NaN     S30-E6     NaN  NaN  Nominee
# 23                NaN     S30-E6     NaN  NaN  Nominee
# 26                NaN    S29-E14     NaN  NaN  Nominee
# 27                NaN    S29-E14     NaN  NaN  Nominee
# ...               ...        ...     ...  ...      ...
# 1235              NaN    S13-E11     NaN  NaN  Nominee
# 1236              NaN    S13-E11     NaN  NaN  Nominee
# 1237              NaN     S13-E9     NaN  NaN  Nominee
# 1240  Comedy or Drama        NaN     NaN  NaN  Nominee
# 1241              NaN        NaN     NaN  NaN  Nominee
#
# [805 rows x 11 columns]

# %% [markdown]
# me quedo con los ganadores

# %%
premios = premios[premios['result'] != 'Nominee']

# %%
pd.DataFrame(premios.isnull().sum() / premios.shape[0] * 100, columns = ["%_nulos"])
# Out:
#                   %_nulos
# award_id         0.000000
# organization     0.000000
# year             0.000000
# award_category   0.000000
# award            0.227790
# person          17.312073
# role            41.685649
# episode_id      29.840547
# season          99.088838
# song            98.633257
# result           0.000000

# %% [markdown]
# Dropeo las columnas que tienen muchos nulos

# %%
col = ['organization', 'role', 'season', 'song']
premios = premios.drop(col, axis=1)

# %%
premios.loc[premios['award_category'] == 'Peabody Award', 'award'] = 'Peabody Award'

# %%
col = ['person', 'episode_id']
premios[col] = premios[col].fillna('desconocido')

# %%
col = ['result']
premios = premios.drop(col, axis=1)

# %%
premios.columns = ['year', 'category', 'award', 'person', 'episode_id']

# %%
premios.to_csv('files/clean_files/premios.csv')

# %%
cameos = pd.read_csv('https://raw.githubusercontent.com/Havilongo/NLP/main/Simpsons/Data/person.csv')

# %%
cameos['name'].value_counts()
# Out:
# name
# Patrick Williams        2
# Tom Brady               2
# Michael Cera            1
# Rachel Reed             1
# Kenneth M. Kinoshita    1
#                        ..
# Joyce Carol Oates       1
# Harold M. Schulweis     1
# Tom Gammill             1
# Leasa Epps-Eisele       1
# Colin Campbell          1
# Name: count, Length: 2627, dtype: int64

# %%
df = pd.read_csv('files/clean_files/guion_clean.csv')

# %%
df
# Out:
#         Unnamed: 0 character_id location_id raw_character_text  \
# 0                0      unkwown         1.0            unkwown
# 1                1      unkwown         2.0            unkwown
# 2                2            1         2.0      Marge Simpson
# 3                3            2         2.0      Homer Simpson
# 4                4            2         2.0      Homer Simpson
# ...            ...          ...         ...                ...
# 143388      143388      unkwown     unkwown            unkwown
# 143389      143389      unkwown     unkwown            unkwown
# 143390      143390      unkwown     unkwown            unkwown
# 143391      143391      unkwown     unkwown            unkwown
# 143392      143392      unkwown     unkwown            unkwown
#
#        raw_location_text                    spoken_words word_count  \
# 0                 Street                         unkwown    unkwown
# 1                    Car                         unkwown    unkwown
# 2                    Car            Ooo, careful, Homer.        3.0
# 3                    Car  There's no time to be careful.        6.0
# 4                    Car                     We're late.        2.0
# ...                  ...                             ...        ...
# 143388           unkwown                         unkwown    unkwown
# 143389           unkwown                         unkwown    unkwown
# 143390           unkwown                         unkwown    unkwown
# 143391           unkwown                         unkwown    unkwown
# 143392           unkwown                         unkwown    unkwown
#
#                                     title episode_id
# 0       Simpsons Roasting on an Open Fire      S1-E1
# 1       Simpsons Roasting on an Open Fire      S1-E1
# 2       Simpsons Roasting on an Open Fire      S1-E1
# 3       Simpsons Roasting on an Open Fire      S1-E1
# 4       Simpsons Roasting on an Open Fire      S1-E1
# ...                                   ...        ...
# 143388                       Fland Canyon    S27-E19
# 143389               To Courier with Love    S27-E20
# 143390                        Simprovised    S27-E21
# 143391           Orange Is the New Yellow    S27-E22
# 143392        Monty Burns' Fleeing Circus     S28-E1
#
# [143393 rows x 9 columns]

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/Havilongo/NLP/main/Simpsons/Data/simpsons_script_lines.csv')
# Out:
# C:\Users\theja\AppData\Local\Temp\ipykernel_37404\2396197924.py:1: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('https://raw.githubusercontent.com/Havilongo/NLP/main/Simpsons/Data/simpsons_script_lines.csv')

# %%
df2
# Out:
#          index    id  episode_id  number  \
# 0            0  9549          32     209
# 1            1  9550          32     210
# 2            2  9551          32     211
# 3            3  9552          32     212
# 4            4  9553          32     213
# ...        ...   ...         ...     ...
# 158243  158243  9544          32     204
# 158244  158244  9545          32     205
# 158245  158245  9546          32     206
# 158246  158246  9547          32     207
# 158247  158247  9548          32     208
#
#                                                  raw_text timestamp_in_ms  \
# 0       Miss Hoover: No, actually, it was a little of ...          848000
# 1       Lisa Simpson: (NEAR TEARS) Where's Mr. Bergstrom?          856000
# 2       Miss Hoover: I don't know. Although I'd sure l...          856000
# 3                Lisa Simpson: That life is worth living.          864000
# 4       Edna Krabappel-Flanders: The polls will be ope...          864000
# ...                                                   ...             ...
# 158243       Miss Hoover: (OFF LISA'S REACTION) I'm back.          831000
# 158244  Miss Hoover: You see, class, my Lyme disease t...          839000
# 158245                    Miss Hoover: Psy-cho-so-ma-tic.          842000
# 158246       Ralph Wiggum: Does that mean you were crazy?          844000
# 158247           JANEY: No, that means she was faking it.          845000
#
#        speaking_line character_id  location_id       raw_character_text  \
# 0               True        464.0          3.0              Miss Hoover
# 1               True          9.0          3.0             Lisa Simpson
# 2               True        464.0          3.0              Miss Hoover
# 3               True          9.0          3.0             Lisa Simpson
# 4               True         40.0          3.0  Edna Krabappel-Flanders
# ...              ...          ...          ...                      ...
# 158243          true          464          3.0              Miss Hoover
# 158244          true          464          3.0              Miss Hoover
# 158245          true          464          3.0              Miss Hoover
# 158246          true          119          3.0             Ralph Wiggum
# 158247          true            4          3.0                    JANEY
#
#                     raw_location_text  \
# 0       Springfield Elementary School
# 1       Springfield Elementary School
# 2       Springfield Elementary School
# 3       Springfield Elementary School
# 4       Springfield Elementary School
# ...                               ...
# 158243  Springfield Elementary School
# 158244  Springfield Elementary School
# 158245  Springfield Elementary School
# 158246  Springfield Elementary School
# 158247  Springfield Elementary School
#
#                                              spoken_words  \
# 0       No, actually, it was a little of both. Sometim...
# 1                                  Where's Mr. Bergstrom?
# 2       I don't know. Although I'd sure like to talk t...
# 3                              That life is worth living.
# 4       The polls will be open from now until the end ...
# ...                                                   ...
# 158243                                          I'm back.
# 158244  You see, class, my Lyme disease turned out to ...
# 158245                                 Psy-cho-so-ma-tic.
# 158246                     Does that mean you were crazy?
# 158247                  No, that means she was faking it.
#
#                                           normalized_text  word_count
# 0       no actually it was a little of both sometimes ...        31.0
# 1                                     wheres mr bergstrom         3.0
# 2       i dont know although id sure like to talk to h...        22.0
# 3                               that life is worth living         5.0
# 4       the polls will be open from now until the end ...        33.0
# ...                                                   ...         ...
# 158243                                            im back         2.0
# 158244     you see class my lyme disease turned out to be        10.0
# 158245                                  psy-cho-so-ma-tic         1.0
# 158246                      does that mean you were crazy         6.0
# 158247                    no that means she was faking it         7.0
#
# [158248 rows x 14 columns]
